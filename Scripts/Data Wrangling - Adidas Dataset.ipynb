# %% [markdown]
# # Data Wrangling Adidas Dataset

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
# Setting up path in case I end up referencing it a lot
path = r'C:\Users\steve\OneDrive\Documents\Career Foundry\Achievement_6'

# %%
# Assigning the dataset to the variable df
df=pd.read_excel(os.path.join(path, 'AdidasDataset.xlsx'))

# %%
df.head()
# Out:
#    Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0         NaN          NaN  Adidas Sales Database                  NaN
# 1         NaN          NaN                    NaN                  NaN
# 2         NaN          NaN                    NaN                  NaN
# 3         NaN     Retailer            Retailer ID         Invoice Date
# 4         NaN  Foot Locker                1185732  2020-01-01 00:00:00
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6             Unnamed: 7      Unnamed: 8  \
# 0        NaN        NaN        NaN                    NaN             NaN
# 1        NaN        NaN        NaN                    NaN             NaN
# 2        NaN        NaN        NaN                    NaN             NaN
# 3     Region      State       City                Product  Price per Unit
# 4  Northeast   New York   New York  Men's Street Footwear              50
#
#    Unnamed: 9  Unnamed: 10       Unnamed: 11       Unnamed: 12   Unnamed: 13
# 0         NaN          NaN               NaN               NaN           NaN
# 1         NaN          NaN               NaN               NaN           NaN
# 2         NaN          NaN               NaN               NaN           NaN
# 3  Units Sold  Total Sales  Operating Profit  Operating Margin  Sales Method
# 4        1200       600000            300000               0.5      In-store

# %% [markdown]
# Looks like we gotta drop the Unnamed: 0 column first and foremost.  Rows 0 seems to contain the title of the dataset, so we can remove that.  Rows 0, 1, and 2 appear to be spacing/empty values so those can be removed as well.

# %% [markdown]
# ## Removing Unneccesary Columns & Rows

# %%
# Dropping Unnamed: 0 column
df=df.drop(columns=['Unnamed: 0'])

# %%
# Dropping rows that were unnecessary
df.drop([0,1,2],inplace=True)

# %%
df.head()
# Out:
#     Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3     Retailer  Retailer ID         Invoice Date     Region      State
# 4  Foot Locker      1185732  2020-01-01 00:00:00  Northeast   New York
# 5  Foot Locker      1185732  2020-01-02 00:00:00  Northeast   New York
# 6  Foot Locker      1185732  2020-01-03 00:00:00  Northeast   New York
# 7  Foot Locker      1185732  2020-01-04 00:00:00  Northeast   New York
#
#   Unnamed: 6                 Unnamed: 7      Unnamed: 8  Unnamed: 9  \
# 3       City                    Product  Price per Unit  Units Sold
# 4   New York      Men's Street Footwear              50        1200
# 5   New York    Men's Athletic Footwear              50        1000
# 6   New York    Women's Street Footwear              40        1000
# 7   New York  Women's Athletic Footwear              45         850
#
#    Unnamed: 10       Unnamed: 11       Unnamed: 12   Unnamed: 13
# 3  Total Sales  Operating Profit  Operating Margin  Sales Method
# 4       600000            300000               0.5      In-store
# 5       500000            150000               0.3      In-store
# 6       400000            140000              0.35      In-store
# 7       382500            133875              0.35      In-store

# %%
new_header = df.iloc[0] #grab the third row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header

# %% [markdown]
# ## Cleaning/Renaming Headers

# %%
df.rename(columns={'Retailer':'retailer','Retailer ID':'retailer_id', 'Invoice Date':'invoice','Region':'region','State':'state','City':'city','Product':'product','Price per Unit':'price_per_unit','Units Sold':'units_sold','Total Sales':'income','Operating Profit':'profit','Operating Margin':'profit_margin','Sales Method':'sales_method'},inplace=True)

# %%
df.reset_index(drop=True,inplace=True)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.head()
# Out:
# 3     retailer              invoice     region     state      city  \
# 0  Foot Locker  2020-01-01 00:00:00  Northeast  New York  New York
# 1  Foot Locker  2020-01-02 00:00:00  Northeast  New York  New York
# 2  Foot Locker  2020-01-03 00:00:00  Northeast  New York  New York
# 3  Foot Locker  2020-01-04 00:00:00  Northeast  New York  New York
# 4  Foot Locker  2020-01-05 00:00:00  Northeast  New York  New York
#
# 3                    product price_per_unit units_sold  income  profit  \
# 0      Men's Street Footwear             50       1200  600000  300000
# 1    Men's Athletic Footwear             50       1000  500000  150000
# 2    Women's Street Footwear             40       1000  400000  140000
# 3  Women's Athletic Footwear             45        850  382500  133875
# 4              Men's Apparel             60        900  540000  162000
#
# 3 profit_margin sales_method
# 0           0.5     In-store
# 1           0.3     In-store
# 2          0.35     In-store
# 3          0.35     In-store
# 4           0.3     In-store

# %% [markdown]
# ## Checking Data Numbers for Consistency or Issues

# %%
df.describe()
# Out:
# 3          retailer              invoice region       state      city  \
# count          9648                 9648   9648        9648      9648
# unique            6                  724      5          50        52
# top     Foot Locker  2021-01-17 00:00:00   West  California  Portland
# freq           2637                   77   2448         432       360
#
# 3                     product  price_per_unit  units_sold  income  profit  \
# count                    9648            9648        9648    9648    9648
# unique                      6             146         361    3512    6510
# top     Men's Street Footwear              50         225  100000   21000
# freq                     1610             557         207      52      34
#
# 3       profit_margin sales_method
# count         9648.00         9648
# unique         127.00            3
# top              0.35       Online
# freq          1229.00         4889

# %%
df.min()
# Out:
# 3
# retailer                       Amazon
# retailer_id                   1128299
# invoice           2020-01-01 00:00:00
# region                        Midwest
# state                         Alabama
# city                           Albany
# product                 Men's Apparel
# price_per_unit                      7
# units_sold                          0
# income                              0
# profit                              0
# profit_margin                     0.1
# sales_method                 In-store
# dtype: object

# %%
df['retailer'].value_counts()
# Out:
# retailer
# Foot Locker      2637
# West Gear        2374
# Sports Direct    2032
# Kohl's           1030
# Amazon            949
# Walmart           626
# Name: count, dtype: int64

# %% [markdown]
# The retailer_id column doesn't really make sense.  There are 6 retailers and 4 retailer ID's.  I could not find any correlation between the retailer_id in relation to retailers, sales method, profit_margine, etc.  Due to that, I will drop the column

# %%
df=df.drop(columns=['retailer_id'])

# %%
df.head()
# Out:
# 3     retailer              invoice     region     state      city  \
# 4  Foot Locker  2020-01-01 00:00:00  Northeast  New York  New York
# 5  Foot Locker  2020-01-02 00:00:00  Northeast  New York  New York
# 6  Foot Locker  2020-01-03 00:00:00  Northeast  New York  New York
# 7  Foot Locker  2020-01-04 00:00:00  Northeast  New York  New York
# 8  Foot Locker  2020-01-05 00:00:00  Northeast  New York  New York
#
# 3                    product price_per_unit units_sold  income  profit  \
# 4      Men's Street Footwear             50       1200  600000  300000
# 5    Men's Athletic Footwear             50       1000  500000  150000
# 6    Women's Street Footwear             40       1000  400000  140000
# 7  Women's Athletic Footwear             45        850  382500  133875
# 8              Men's Apparel             60        900  540000  162000
#
# 3 profit_margin sales_method
# 4           0.5     In-store
# 5           0.3     In-store
# 6          0.35     In-store
# 7          0.35     In-store
# 8           0.3     In-store

# %% [markdown]
# The 0 for profit, income, etc seems off, going to see what is going on there

# %%
df2 = df[(df == 0).any(axis=1)]

# %%
df2
# Out:
# 3        retailer              invoice   region     state   city  \
# 1019  Foot Locker  2021-06-05 00:00:00  Midwest  Nebraska  Omaha
# 1025  Foot Locker  2021-06-11 00:00:00  Midwest  Nebraska  Omaha
# 4907  Foot Locker  2021-06-05 00:00:00  Midwest  Nebraska  Omaha
# 4913  Foot Locker  2021-06-11 00:00:00  Midwest  Nebraska  Omaha
#
# 3                       product price_per_unit units_sold income profit  \
# 1019  Women's Athletic Footwear             35          0      0      0
# 1025  Women's Athletic Footwear             30          0      0      0
# 4907  Women's Athletic Footwear             33          0      0      0
# 4913  Women's Athletic Footwear             27          0      0      0
#
# 3    profit_margin sales_method
# 1019           0.4       Outlet
# 1025           0.4       Outlet
# 4907          0.55       Online
# 4913          0.53       Online

# %% [markdown]
# Looks to only be 4 rows, going to try to remove those 4 rows.

# %%
df.shape
# Out:
# (9648, 12)

# %%
df = df[(df != 0).all(axis=1)]

# %%
df.shape
# Out:
# (9644, 12)

# %% [markdown]
# Looks good, 4 rows removed using the same process that located them in the first place, just updated the == to != to recreate the dataset without those entries.  Did not have to target specific columns due to those 4 rows having the only instances of 0 when I checked in Excel.

# %%
# Saving for future use
df.to_excel(os.path.join(path,'AdidasDatasetUpdated.xlsx'))
